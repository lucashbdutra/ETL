# %%
import pandas as pd
import pandera as pa

# %%
df = pd.read_csv('ocorrencia.csv', parse_dates=['ocorrencia_dia'], dayfirst=True) #fazer a leitura da tablea, parse_data: faz a conversão para data e dayfirst: faz com que o dia seja o primeiro número
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
# 5            SALVADOR            BA                 ****     2010-01-06
# 6               COARI            AM                 SBUY     2010-01-07
# 7            CANUTAMA            AM                 ****     2010-01-09
# 8            CASCAVEL            PR                 SBCA     2010-01-10
# 9       PARÁ DE MINAS            MG                 ****     2010-01-10
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0
# 5        17:53:00                    0
# 6        18:40:00                    0
# 7        12:30:00                    3
# 8        23:15:00                    2
# 9        20:00:00                    0

# %%
schema = pa.DataFrameSchema( #cria um esquema para o data frame para fazer as validações
    columns = {
    'codigo':pa.Column(pa.Int, required=False), # O valor required (necessário) é True por padrao, colocando assim essa passa a ser uma coluna opcional, em caso de ausência não havera erro.
    'codigo_ocorrencia':pa.Column(pa.Int),# diz que a primeira coluna tem que ser int
    'codigo_ocorrencia2':pa.Column(pa.Int), # e assim por diante, verificando o tipo de cada coluna
    'ocorrencia_classificacao':pa.Column(pa.String),
    'ocorrencia_cidade':pa.Column(pa.String),
    'ocorrencia_uf':pa.Column(pa.String, pa.Check.str_length(2,2)), # verifica o tamanho min e max
    'ocorrencia_aerodromo':pa.Column(pa.String),
    'ocorrencia_dia':pa.Column(pa.DateTime),
    'ocorrencia_hora':pa.Column(pa.String, pa.Check.str_matches(r'([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'),nullable=True), #nullable é pra permitir valores nulos
    'total_recomendacoes':pa.Column(pa.Int) #essa expressão recular acima faz a validação das horas, minutos e segundos
    }
)

# %%
schema.validate(df)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# <ipython-input-7-dc85ea979a2b> in <module>
# ----> 1 schema.validate(df)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     610                 check_results.append(isinstance(result, pd.DataFrame))
#     611             except errors.SchemaError as err:
# --> 612                 error_handler.collect_error("schema_component_check", err)
#     613             except errors.SchemaErrors as err:
#     614                 for schema_error_dict in err.schema_errors:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandera/error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     606                     lazy=lazy,
#     607                     # don't make a copy of the data
# --> 608                     inplace=True,
#     609                 )
#     610                 check_results.append(isinstance(result, pd.DataFrame))
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandera/schemas.py in __call__(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1903         """Alias for ``validate`` method."""
#    1904         return self.validate(
# -> 1905             check_obj, head, tail, sample, random_state, lazy, inplace
#    1906         )
#    1907
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandera/schema_components.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     221                     )
#     222             else:
# --> 223                 validate_column(check_obj, column_name)
#     224
#     225         return check_obj
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandera/schema_components.py in validate_column(check_obj, column_name)
#     201                 random_state,
#     202                 lazy,
# --> 203                 inplace=inplace,
#     204             )
#     205
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1860                 )
#    1861             except errors.SchemaError as err:
# -> 1862                 error_handler.collect_error("dataframe_check", err)
#    1863             except Exception as err:  # pylint: disable=broad-except
#    1864                 # catch other exceptions that may occur when executing the
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandera/error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1856                 check_results.append(
#    1857                     _handle_check_results(
# -> 1858                         self, check_index, check, check_obj, *check_args
#    1859                     )
#    1860                 )
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandera/schemas.py in _handle_check_results(schema, check_index, check, check_obj, *check_args)
#    2201             check=check,
#    2202             check_index=check_index,
# -> 2203             check_output=check_result.check_output,
#    2204         )
#    2205     return check_result.check_passed
#
# SchemaError: <Schema Column(name=ocorrencia_uf, type=DataType(str))> failed element-wise validator 0:
# <Check str_length: str_length(2, 2)>
# failure cases:
#    index failure_case
# 0   2227          ***
# 1   5841          ***

# %% [raw]
# df.dtypes
# df.ocorrencia_dia.dt.month

# %% [raw]
# pip install pandera
